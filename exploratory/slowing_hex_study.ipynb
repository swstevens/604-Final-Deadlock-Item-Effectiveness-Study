# %% [markdown]
# # Slowing Hex — Deep Dive
#
# Our classification table marked Slowing Hex as **Overrated** against Mina: teams buy it significantly more when Mina is present, but the win-rate lift doesn't survive significance testing per tier.
#
# This notebook investigates why:
# - Is Slowing Hex a core item that many heroes build every game regardless of matchup?
# - Where does the win-rate signal appear and where does it drop off across skill tiers?
# - Does the 'always buy it' behaviour of certain heroes inflate the counter-item signal?

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from scipy.stats import chi2_contingency
from statsmodels.stats.proportion import proportions_ztest

pd.set_option('display.max_columns', None)

SLOWING_HEX_ID = np.uint32(1813726886)
SKILL_CUTS     = {'low': (0, 99), 'high': (100, 9999)}
OTHER_TEAM     = {'Team0': 'Team1', 'Team1': 'Team0'}

def cramers_v(chi2_stat, n):
    return float(np.sqrt(chi2_stat / n)) if n > 0 else 0.0

# %%
items_lookup  = pd.read_parquet('data/public_items.parquet')
heroes_lookup = pd.read_parquet('data/public_heroes.parquet')
for col in items_lookup.columns:
    items_lookup[col] = items_lookup[col].apply(lambda x: x.decode() if isinstance(x, bytes) else x)

upgrade_item_ids = set(items_lookup[items_lookup['type'] == 'upgrade']['id'])
item_id_to_name  = items_lookup.set_index('id')['name'].to_dict()
hero_id_to_name  = heroes_lookup.set_index('id')['name'].to_dict()
MINA_ID      = heroes_lookup[heroes_lookup['name'] == 'Mina']['id'].iloc[0]
print(f'Mina hero_id: {MINA_ID}')
# Out:
# Mina hero_id: 63

# %%
import os

DATA_FILES       = ['data/collected_matches.jsonl', 'data/collected_matches_gap.jsonl']
HIGH_RANK_BADGE  = 100   # avg_badge >= 100 on BOTH teams → high-rank match

player_rows = []
item_rows   = []
meta_rows   = []

for path in DATA_FILES:
    if not os.path.exists(path):
        print(f'  {path} not found — skipping')
        continue
    with open(path) as f:
        for line in f:
            try:
                match = json.loads(line)
            except json.JSONDecodeError:
                continue
            b0 = match['average_badge_team0']
            b1 = match['average_badge_team1']
            # Keep only matches where both teams qualify as high rank
            if b0 < HIGH_RANK_BADGE or b1 < HIGH_RANK_BADGE:
                continue
            mid = match['match_id']
            won = match['winning_team']
            meta_rows.append({
                'match_id':    mid,
                'winning_team':won,
                'duration_s':  match['duration_s'],
                'start_time':  match['start_time'],
                'badge_team0': b0,
                'badge_team1': b1,
            })
            for p in match['players']:
                team    = p['team']
                hero_id = p['hero_id']
                player_rows.append({'match_id': mid, 'team': team, 'hero_id': hero_id,
                                     'won': int(team == won)})
                for item in p['items']:
                    iid = np.uint32(item['item_id'])
                    if iid not in upgrade_item_ids:
                        continue
                    item_rows.append({'match_id': mid, 'team': team, 'hero_id': hero_id,
                                       'won': int(team == won), 'item_id': iid,
                                       'held':     item['sold_time_s'] == 0,
                                       'was_sold': item['sold_time_s'] >  0})

players_df = pd.DataFrame(player_rows)
players_df['hero_name'] = players_df['hero_id'].map(hero_id_to_name)
items_df   = pd.DataFrame(item_rows)
items_df['item_name'] = items_df['item_id'].map(item_id_to_name)
meta_df    = pd.DataFrame(meta_rows)

# badge per (match, team) — all rows are high rank by construction
badge_long = pd.melt(meta_df, id_vars=['match_id'],
                     value_vars=['badge_team0', 'badge_team1'],
                     var_name='_', value_name='avg_badge')
badge_long['team'] = badge_long['_'].map({'badge_team0': 'Team0', 'badge_team1': 'Team1'})
badge_long['skill_tier'] = 'high'
badge_long = badge_long[['match_id', 'team', 'avg_badge', 'skill_tier']]

print(f'High-rank matches (both teams avg_badge ≥ {HIGH_RANK_BADGE}): {len(meta_df):,}')
print(f'Player rows: {len(players_df):,}  |  Item rows: {len(items_df):,}')
# Out:
# High-rank matches (both teams avg_badge ≥ 100): 15,104
# Player rows: 181,248  |  Item rows: 2,886,340

# %% [markdown]
# ## 1. Hold rate and win rate — all matchups (high rank only)
#
# First question: is Slowing Hex actually good in general at high rank, or is it being bought because players think it counters Mina?

# %%
# Per (match, team): did they hold Slowing Hex?
slowing_hex_held = (
    items_df[(items_df['item_id'] == SLOWING_HEX_ID) & items_df['held']]
    .groupby(['match_id', 'team'])
    .size().gt(0).astype(int)
    .rename('held_slowing_hex')
    .reset_index()
)

outcomes = players_df[['match_id', 'team', 'won']].drop_duplicates()

team_df = (
    outcomes
    .merge(badge_long,       on=['match_id', 'team'])
    .merge(slowing_hex_held, on=['match_id', 'team'], how='left')
)
team_df['held_slowing_hex'] = team_df['held_slowing_hex'].fillna(0).astype(int)

held     = team_df[team_df['held_slowing_hex'] == 1]['won']
not_held = team_df[team_df['held_slowing_hex'] == 0]['won']

ct = np.array([[int(held.sum()),     len(held)     - int(held.sum())],
               [int(not_held.sum()), len(not_held) - int(not_held.sum())]])
chi2_overall, p_overall, _, _ = chi2_contingency(ct, correction=True)
v_overall = cramers_v(chi2_overall, ct.sum())

summary = {
    'n_teams':     len(team_df),
    'n_held':      len(held),
    'hold_rate':   len(held) / len(team_df),
    'wr_held':     held.mean(),
    'wr_not_held': not_held.mean(),
    'wr_delta':    held.mean() - not_held.mean(),
    'chi2':        round(chi2_overall, 3),
    'p_value':     round(p_overall, 4),
    "cramers_v":   round(v_overall, 4),
}
display(pd.DataFrame([summary]).round(3))

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(['High rank'], [summary['hold_rate']], color='steelblue', alpha=0.85)
axes[0].set_ylabel('Hold rate')
axes[0].set_title('Slowing Hex hold rate (high rank)')
axes[0].yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
axes[0].set_ylim(0, max(summary['hold_rate'] * 1.4, 0.1))
axes[0].grid(axis='y', alpha=0.3)

w = 0.35
x = np.array([0])
axes[1].bar(x - w/2, [summary['wr_held']],     w, label='Held',     color='steelblue',      alpha=0.85)
axes[1].bar(x + w/2, [summary['wr_not_held']], w, label='Not held', color='lightsteelblue', alpha=0.85)
delta = summary['wr_delta']
color = 'green' if delta > 0 else 'red'
axes[1].annotate(f"{delta:+.1%}\nV={v_overall:.3f}  p={p_overall:.4f}",
                 xy=(0, max(summary['wr_held'], summary['wr_not_held']) + 0.01),
                 ha='center', fontsize=9, color=color, fontweight='bold')
axes[1].axhline(0.5, color='grey', linewidth=0.8, linestyle='--')
axes[1].set_xticks(x); axes[1].set_xticklabels(['High rank'])
axes[1].set_ylim(0, 0.75); axes[1].set_ylabel('Win rate')
axes[1].set_title('Win rate: Slowing Hex held vs not (all matchups)')
axes[1].yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
axes[1].legend(); axes[1].grid(axis='y', alpha=0.3)

plt.suptitle('Slowing Hex — general effectiveness (high rank, both teams avg_badge ≥ 100)', fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Which heroes build Slowing Hex regardless of matchup?
#
# If certain heroes treat it as a core item, their presence inflates the counter-item signal.

# %%
slowing_hex_by_hero = (
    items_df[items_df['item_id'] == SLOWING_HEX_ID]
    .groupby('hero_id')
    .agg(times_bought=('held', 'count'), times_held=('held', 'sum'))
    .reset_index()
)
slowing_hex_by_hero['hero_name']  = slowing_hex_by_hero['hero_id'].map(hero_id_to_name)
hero_games                   = players_df.groupby('hero_id').size().rename('games')
slowing_hex_by_hero               = slowing_hex_by_hero.merge(hero_games, on='hero_id')
slowing_hex_by_hero['hold_rate']  = slowing_hex_by_hero['times_held']  / slowing_hex_by_hero['games']
slowing_hex_by_hero['buy_rate']   = slowing_hex_by_hero['times_bought'] / slowing_hex_by_hero['games']
slowing_hex_by_hero               = slowing_hex_by_hero.sort_values('hold_rate', ascending=False)

display(slowing_hex_by_hero[['hero_name', 'games', 'times_held', 'hold_rate', 'buy_rate']].round(3))

top = slowing_hex_by_hero.head(15)
fig, ax = plt.subplots(figsize=(11, 4))
x = np.arange(len(top))
ax.bar(x, top['hold_rate'], color='steelblue', alpha=0.85, label='Held at game end')
ax.bar(x, top['buy_rate'] - top['hold_rate'], bottom=top['hold_rate'],
       color='lightsteelblue', alpha=0.85, label='Bought then sold')
ax.set_xticks(x); ax.set_xticklabels(top['hero_name'], rotation=30, ha='right')
ax.set_ylabel('Rate (per game played)')
ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
ax.set_title('Slowing Hex hold/buy rate per hero (top 15) — all matchups')
ax.legend(); ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#       hero_name  games  times_held  hold_rate  buy_rate
# 7       Paradox   5292        1609      0.304     0.402
# 10         Haze  10472        2899      0.277     0.385
# 12        Bebop   8516        1502      0.176     0.207
# 18       Warden   4179         679      0.162     0.200
# 30        Paige   5909         789      0.134     0.334
# 31  The Doorman   4019         502      0.125     0.483
# 35          Rem   3309         386      0.117     0.174
# 11     Holliday   3656         349      0.095     0.140
# 9        Kelvin   3139         260      0.083     0.094
# 27      Drifter   6328         504      0.080     0.101
# 17          Ivy   5053         396      0.078     0.344
# 25     Sinclair   2582         183      0.071     0.121
# 32        Billy   4817         253      0.053     0.080
# 8        Dynamo   5663         276      0.049     0.073
# 33       Graves   2765         121      0.044     0.059
# 24        Vyper   2648         109      0.041     0.051
# ...

# %% [markdown]
# ## 3. The 2×2 breakdown: Mina present × Slowing Hex held
#
# Four cells, each showing win rate and count. This separates:
# - Teams that bought Dispel specifically because Mina was there
# - Teams that bought it regardless
# - Teams facing Mina who didn't buy it

# %%
# Enemy Mina flag per (match, team)
mina_on_enemy = (
    players_df[players_df['hero_id'] == MINA_ID][['match_id', 'team']]
    .assign(enemy_mina=1)
    .assign(team=lambda df: df['team'].map(OTHER_TEAM))
)

team_df2 = team_df.merge(mina_on_enemy, on=['match_id', 'team'], how='left')
team_df2['enemy_mina'] = team_df2['enemy_mina'].fillna(0).astype(int)

grid = (
    team_df2
    .groupby(['enemy_mina', 'held_slowing_hex'])
    .agg(n=('won', 'count'), wins=('won', 'sum'))
    .assign(win_rate=lambda d: d['wins'] / d['n'])
    .reset_index()
)

# Cramer's V on the full 2×2 (Mina present × Slowing Hex held)
ct_2x2 = pd.crosstab(team_df2['enemy_mina'], team_df2['held_slowing_hex'])
chi2_2x2, p_2x2, _, _ = chi2_contingency(ct_2x2.values, correction=True)
v_2x2 = cramers_v(chi2_2x2, ct_2x2.values.sum())
print(f'Mina present × Slowing Hex held — χ²={chi2_2x2:.3f}  p={p_2x2:.4f}  V={v_2x2:.4f}')

# Cramer's V on win rate: Slowing Hex held × won, within Mina matchups only
facing_mina = team_df2[team_df2['enemy_mina'] == 1]
ct_mina = pd.crosstab(facing_mina['held_slowing_hex'], facing_mina['won'])
chi2_mina, p_mina, _, _ = chi2_contingency(ct_mina.values, correction=True)
v_mina = cramers_v(chi2_mina, ct_mina.values.sum())
print(f'Win rate association vs Mina (held × won) — χ²={chi2_mina:.3f}  p={p_mina:.4f}  V={v_mina:.4f}')

grid['enemy_mina']       = grid['enemy_mina'].map({0: 'Mina absent', 1: 'Mina present'})
grid['held_slowing_hex'] = grid['held_slowing_hex'].map({0: 'Slowing Hex NOT held', 1: 'Slowing Hex held'})
display(grid.round(3))

# Heatmap-style 2×2
pivot_wr = grid.pivot(index='held_slowing_hex', columns='enemy_mina', values='win_rate')
pivot_n  = grid.pivot(index='held_slowing_hex', columns='enemy_mina', values='n')

fig, ax = plt.subplots(figsize=(7, 4))
im = ax.imshow(pivot_wr.values, cmap='RdYlGn', vmin=0.35, vmax=0.65, aspect='auto')
ax.set_xticks([0, 1]); ax.set_xticklabels(pivot_wr.columns, fontsize=10)
ax.set_yticks([0, 1]); ax.set_yticklabels(pivot_wr.index,   fontsize=10)
for i in range(2):
    for j in range(2):
        wr = pivot_wr.values[i, j]
        n  = int(pivot_n.values[i, j])
        ax.text(j, i, f'{wr:.1%}\n(n={n:,})', ha='center', va='center',
                fontsize=12, fontweight='bold',
                color='white' if wr < 0.42 or wr > 0.58 else 'black')
plt.colorbar(im, ax=ax, label='Win rate')
ax.set_title(
    f'Slowing Hex × Mina — win rate 2×2\n'
    f'(high rank, avg_badge ≥ 100)\n'
    f'purchase χ²: V={v_2x2:.3f} p={p_2x2:.4f}  |  win-rate χ²: V={v_mina:.3f} p={p_mina:.4f}',
    fontsize=10,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Core builders vs situational buyers
#
# Split the Slowing Hex holders into:
# - **Core builders**: heroes whose hold rate ≥ 20% (they build it most games)
# - **Situational buyers**: everyone else
#
# Then check whether the win rate difference against Mina comes from core builders (confound) or situational buyers (genuine counter signal).

# %%
CORE_THRESHOLD = 0.20

core_heroes = set(
    slowing_hex_by_hero[slowing_hex_by_hero['hold_rate'] >= CORE_THRESHOLD]['hero_id']
)
print(f'Core Slowing Hex builders (hold rate ≥ {CORE_THRESHOLD:.0%}):')
print(slowing_hex_by_hero[slowing_hex_by_hero['hold_rate'] >= CORE_THRESHOLD][['hero_name', 'hold_rate']].to_string(index=False))

# Tag each player's team as containing a core builder or not
has_core_builder = (
    players_df[players_df['hero_id'].isin(core_heroes)]
    .groupby(['match_id', 'team'])
    .size().gt(0).astype(int)
    .rename('has_core_builder')
    .reset_index()
)

team_df3 = team_df2.merge(has_core_builder, on=['match_id', 'team'], how='left')
team_df3['has_core_builder'] = team_df3['has_core_builder'].fillna(0).astype(int)

rows = []
for builder_label, builder_mask in [('Core builder on team', 1), ('No core builder', 0)]:
    for mina_label, mina_mask in [('Mina present', 1), ('Mina absent', 0)]:
        grp      = team_df3[
            (team_df3['has_core_builder'] == builder_mask) &
            (team_df3['enemy_mina']       == mina_mask)
        ]
        held     = grp[grp['held_slowing_hex'] == 1]['won']
        not_held = grp[grp['held_slowing_hex'] == 0]['won']

        # Cramer's V for this cell
        if len(held) >= 5 and len(not_held) >= 5:
            ct_grp = np.array([[int(held.sum()), len(held) - int(held.sum())],
                                [int(not_held.sum()), len(not_held) - int(not_held.sum())]])
            chi2_grp, p_grp, _, _ = chi2_contingency(ct_grp, correction=True)
            v_grp = cramers_v(chi2_grp, ct_grp.sum())
        else:
            p_grp, v_grp = np.nan, np.nan

        rows.append({
            'group':       builder_label,
            'matchup':     mina_label,
            'n_held':      len(held),
            'n_not_held':  len(not_held),
            'wr_held':     held.mean()     if len(held)     > 0 else np.nan,
            'wr_not_held': not_held.mean() if len(not_held) > 0 else np.nan,
            'p_value':     round(p_grp, 4) if not np.isnan(p_grp) else np.nan,
            'cramers_v':   round(v_grp, 4) if not np.isnan(v_grp) else np.nan,
        })

breakdown_df = pd.DataFrame(rows)
breakdown_df['wr_delta'] = breakdown_df['wr_held'] - breakdown_df['wr_not_held']
display(breakdown_df.round(3))

# Plot
fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=True)
mina_labels  = ['Mina absent', 'Mina present']
group_labels = ['Core builder on team', 'No core builder']
x = np.arange(len(mina_labels))
w = 0.35

for ax, group in zip(axes, group_labels):
    sub = breakdown_df[breakdown_df['group'] == group].set_index('matchup').reindex(mina_labels)
    ax.bar(x - w/2, sub['wr_held'],     w, label='Slowing Hex held',     color='steelblue',      alpha=0.85)
    ax.bar(x + w/2, sub['wr_not_held'], w, label='Slowing Hex not held', color='lightsteelblue', alpha=0.85)
    for i, row in enumerate(sub.itertuples()):
        if pd.isna(row.wr_delta): continue
        color = 'green' if row.wr_delta > 0 else 'red'
        v_str = f'  V={row.cramers_v:.3f}' if not pd.isna(row.cramers_v) else ''
        ax.annotate(f'{row.wr_delta:+.1%}{v_str}',
                    xy=(i, max(row.wr_held or 0, row.wr_not_held or 0) + 0.01),
                    ha='center', fontsize=8, color=color, fontweight='bold')
    ax.axhline(0.5, color='grey', linewidth=0.8, linestyle='--')
    ax.set_xticks(x); ax.set_xticklabels(mina_labels, fontsize=9)
    ax.set_ylim(0, 0.80); ax.set_ylabel('Win rate')
    ax.set_title(group)
    ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
    ax.legend(fontsize=8); ax.grid(axis='y', alpha=0.3)

fig.suptitle('Slowing Hex win rate: core builders vs situational buyers × Mina matchup',
             fontsize=11)
plt.tight_layout()
plt.show()
