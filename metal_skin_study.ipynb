# %% [markdown]
# # Metal Skin — Deep Dive
#
# Our classification table marked Metal Skin as **Lose-More** against Vyper: teams buy it significantly more when Vyper is present, but the win-rate association is *negative* — buyers are losing more, not less.
#
# This notebook investigates why:
# - Is Metal Skin a reactive / panic purchase that signals a team is already under pressure?
# - Where does the negative win-rate signal appear and where does it persist across the roster?
# - Does the 'always buy it' behaviour of certain heroes confound the lose-more signal?

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from scipy.stats import chi2_contingency
from statsmodels.stats.proportion import proportions_ztest

pd.set_option('display.max_columns', None)

METAL_SKIN_ID = np.uint32(1378931225)
SKILL_CUTS    = {'low': (0, 99), 'high': (100, 9999)}
OTHER_TEAM    = {'Team0': 'Team1', 'Team1': 'Team0'}

# %%
items_lookup  = pd.read_parquet('data/public_items.parquet')
heroes_lookup = pd.read_parquet('data/public_heroes.parquet')
for col in items_lookup.columns:
    items_lookup[col] = items_lookup[col].apply(lambda x: x.decode() if isinstance(x, bytes) else x)

upgrade_item_ids = set(items_lookup[items_lookup['type'] == 'upgrade']['id'])
item_id_to_name  = items_lookup.set_index('id')['name'].to_dict()
hero_id_to_name  = heroes_lookup.set_index('id')['name'].to_dict()
VYPER_ID         = heroes_lookup[heroes_lookup['name'] == 'Vyper']['id'].iloc[0]
print(f'Vyper hero_id: {VYPER_ID}')
# Out:
# Vyper hero_id: 58

# %%
import os

DATA_FILES       = ['data/collected_matches.jsonl', 'data/collected_matches_gap.jsonl']
HIGH_RANK_BADGE  = 100   # avg_badge >= 100 on BOTH teams → high-rank match

player_rows = []
item_rows   = []
meta_rows   = []

for path in DATA_FILES:
    if not os.path.exists(path):
        print(f'  {path} not found — skipping')
        continue
    with open(path) as f:
        for line in f:
            try:
                match = json.loads(line)
            except json.JSONDecodeError:
                continue
            b0 = match['average_badge_team0']
            b1 = match['average_badge_team1']
            if b0 < HIGH_RANK_BADGE or b1 < HIGH_RANK_BADGE:
                continue
            mid = match['match_id']
            won = match['winning_team']
            meta_rows.append({
                'match_id':    mid,
                'winning_team':won,
                'duration_s':  match['duration_s'],
                'start_time':  match['start_time'],
                'badge_team0': b0,
                'badge_team1': b1,
            })
            for p in match['players']:
                team    = p['team']
                hero_id = p['hero_id']
                player_rows.append({'match_id': mid, 'team': team, 'hero_id': hero_id,
                                     'won': int(team == won)})
                for item in p['items']:
                    iid = np.uint32(item['item_id'])
                    if iid not in upgrade_item_ids:
                        continue
                    item_rows.append({'match_id': mid, 'team': team, 'hero_id': hero_id,
                                       'won': int(team == won), 'item_id': iid,
                                       'held':     item['sold_time_s'] == 0,
                                       'was_sold': item['sold_time_s'] >  0})

players_df = pd.DataFrame(player_rows)
players_df['hero_name'] = players_df['hero_id'].map(hero_id_to_name)
items_df   = pd.DataFrame(item_rows)
items_df['item_name'] = items_df['item_id'].map(item_id_to_name)
meta_df    = pd.DataFrame(meta_rows)

badge_long = pd.melt(meta_df, id_vars=['match_id'],
                     value_vars=['badge_team0', 'badge_team1'],
                     var_name='_', value_name='avg_badge')
badge_long['team'] = badge_long['_'].map({'badge_team0': 'Team0', 'badge_team1': 'Team1'})
badge_long['skill_tier'] = 'high'
badge_long = badge_long[['match_id', 'team', 'avg_badge', 'skill_tier']]

print(f'High-rank matches (both teams avg_badge ≥ {HIGH_RANK_BADGE}): {len(meta_df):,}')
print(f'Player rows: {len(players_df):,}  |  Item rows: {len(items_df):,}')
# Out:
# High-rank matches (both teams avg_badge ≥ 100): 15,104
# Player rows: 181,248  |  Item rows: 2,886,340

# %% [markdown]
# ## 1. Hold rate and win rate — all matchups (high rank only)
#
# First question: is Metal Skin actually bad in general at high rank, or is the negative signal driven entirely by Vyper matchups?

# %%
# Per (match, team): did they hold Metal Skin?
metal_skin_held = (
    items_df[(items_df['item_id'] == METAL_SKIN_ID) & items_df['held']]
    .groupby(['match_id', 'team'])
    .size().gt(0).astype(int)
    .rename('held_metal_skin')
    .reset_index()
)

outcomes = players_df[['match_id', 'team', 'won']].drop_duplicates()

team_df = (
    outcomes
    .merge(badge_long,      on=['match_id', 'team'])
    .merge(metal_skin_held, on=['match_id', 'team'], how='left')
)
team_df['held_metal_skin'] = team_df['held_metal_skin'].fillna(0).astype(int)

held     = team_df[team_df['held_metal_skin'] == 1]['won']
not_held = team_df[team_df['held_metal_skin'] == 0]['won']
summary = {
    'n_teams':     len(team_df),
    'n_held':      len(held),
    'hold_rate':   len(held) / len(team_df),
    'wr_held':     held.mean(),
    'wr_not_held': not_held.mean(),
    'wr_delta':    held.mean() - not_held.mean(),
}
display(pd.DataFrame([summary]).round(3))

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].bar(['High rank'], [summary['hold_rate']], color='firebrick', alpha=0.85)
axes[0].set_ylabel('Hold rate')
axes[0].set_title('Metal Skin hold rate (high rank)')
axes[0].yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
axes[0].set_ylim(0, max(summary['hold_rate'] * 1.4, 0.1))
axes[0].grid(axis='y', alpha=0.3)

w = 0.35
x = np.array([0])
axes[1].bar(x - w/2, [summary['wr_held']],     w, label='Held',     color='firebrick',      alpha=0.85)
axes[1].bar(x + w/2, [summary['wr_not_held']], w, label='Not held', color='lightsalmon',    alpha=0.85)
delta = summary['wr_delta']
color = 'green' if delta > 0 else 'red'
axes[1].annotate(f"{delta:+.1%}",
                 xy=(0, max(summary['wr_held'], summary['wr_not_held']) + 0.01),
                 ha='center', fontsize=10, color=color, fontweight='bold')
axes[1].axhline(0.5, color='grey', linewidth=0.8, linestyle='--')
axes[1].set_xticks(x); axes[1].set_xticklabels(['High rank'])
axes[1].set_ylim(0, 0.75); axes[1].set_ylabel('Win rate')
axes[1].set_title('Win rate: Metal Skin held vs not (all matchups)')
axes[1].yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
axes[1].legend(); axes[1].grid(axis='y', alpha=0.3)

plt.suptitle('Metal Skin — general effectiveness (high rank, both teams avg_badge ≥ 100)', fontsize=11)
plt.tight_layout()
plt.show()
# Out:
#    n_teams  n_held  hold_rate  wr_held  wr_not_held  wr_delta
# 0    30208    5522      0.183    0.431        0.515    -0.084

# %% [markdown]
# ## 2. Which heroes build Metal Skin regardless of matchup?
#
# If certain heroes treat it as a core defensive item, their presence confounds the lose-more signal.

# %%
metal_skin_by_hero = (
    items_df[items_df['item_id'] == METAL_SKIN_ID]
    .groupby('hero_id')
    .agg(times_bought=('held', 'count'), times_held=('held', 'sum'))
    .reset_index()
)
metal_skin_by_hero['hero_name'] = metal_skin_by_hero['hero_id'].map(hero_id_to_name)
hero_games                      = players_df.groupby('hero_id').size().rename('games')
metal_skin_by_hero              = metal_skin_by_hero.merge(hero_games, on='hero_id')
metal_skin_by_hero['hold_rate'] = metal_skin_by_hero['times_held']  / metal_skin_by_hero['games']
metal_skin_by_hero['buy_rate']  = metal_skin_by_hero['times_bought'] / metal_skin_by_hero['games']
metal_skin_by_hero              = metal_skin_by_hero.sort_values('hold_rate', ascending=False)

display(metal_skin_by_hero[['hero_name', 'games', 'times_held', 'hold_rate', 'buy_rate']].round(3))

top = metal_skin_by_hero.head(15)
fig, ax = plt.subplots(figsize=(11, 4))
x = np.arange(len(top))
ax.bar(x, top['hold_rate'], color='firebrick', alpha=0.85, label='Held at game end')
ax.bar(x, top['buy_rate'] - top['hold_rate'], bottom=top['hold_rate'],
       color='lightsalmon', alpha=0.85, label='Bought then sold')
ax.set_xticks(x); ax.set_xticklabels(top['hero_name'], rotation=30, ha='right')
ax.set_ylabel('Rate (per game played)')
ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
ax.set_title('Metal Skin hold/buy rate per hero (top 15) — all matchups')
ax.legend(); ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#       hero_name  games  times_held  hold_rate  buy_rate
# 16         Shiv   7193         849      0.118     0.123
# 36       Silver   2132         217      0.102     0.107
# 37      Celeste   1771         160      0.090     0.093
# 33       Graves   2765         232      0.084     0.086
# 29       Victor   4030         332      0.082     0.084
# 1         Seven   4668         364      0.078     0.080
# 19       Yamato   4806         351      0.073     0.076
# 32        Billy   4817         336      0.070     0.071
# 27      Drifter   6328         435      0.069     0.071
# 34       Apollo   2229         149      0.067     0.070
# 28      Venator   2826         181      0.064     0.065
# 4        Abrams   6499         385      0.059     0.061
# 3    Lady Geist   4198         229      0.055     0.057
# 26         Mina   6102         317      0.052     0.053
# 12        Bebop   8516         419      0.049     0.051
# 0      Infernus   6953         329      0.047     0.049
# ...

# %% [markdown]
# ## 3. The 2×2 breakdown: Vyper present × Metal Skin held
#
# Four cells, each showing win rate and count. This separates:
# - Teams that bought Metal Skin specifically because Vyper was there
# - Teams that bought it regardless
# - Teams facing Vyper who didn't buy it

# %%
# Enemy Vyper flag per (match, team)
vyper_on_enemy = (
    players_df[players_df['hero_id'] == VYPER_ID][['match_id', 'team']]
    .assign(enemy_vyper=1)
    .assign(team=lambda df: df['team'].map(OTHER_TEAM))
)

team_df2 = team_df.merge(vyper_on_enemy, on=['match_id', 'team'], how='left')
team_df2['enemy_vyper'] = team_df2['enemy_vyper'].fillna(0).astype(int)

grid = (
    team_df2
    .groupby(['enemy_vyper', 'held_metal_skin'])
    .agg(n=('won', 'count'), wins=('won', 'sum'))
    .assign(win_rate=lambda d: d['wins'] / d['n'])
    .reset_index()
)
grid['enemy_vyper']      = grid['enemy_vyper'].map({0: 'Vyper absent', 1: 'Vyper present'})
grid['held_metal_skin']  = grid['held_metal_skin'].map({0: 'Metal Skin NOT held', 1: 'Metal Skin held'})
display(grid.round(3))

# Heatmap-style 2x2
pivot_wr = grid.pivot(index='held_metal_skin', columns='enemy_vyper', values='win_rate')
pivot_n  = grid.pivot(index='held_metal_skin', columns='enemy_vyper', values='n')

fig, ax = plt.subplots(figsize=(7, 4))
im = ax.imshow(pivot_wr.values, cmap='RdYlGn', vmin=0.35, vmax=0.65, aspect='auto')
ax.set_xticks([0, 1]); ax.set_xticklabels(pivot_wr.columns, fontsize=10)
ax.set_yticks([0, 1]); ax.set_yticklabels(pivot_wr.index,   fontsize=10)
for i in range(2):
    for j in range(2):
        wr = pivot_wr.values[i, j]
        n  = int(pivot_n.values[i, j])
        ax.text(j, i, f'{wr:.1%}\n(n={n:,})', ha='center', va='center',
                fontsize=12, fontweight='bold',
                color='white' if wr < 0.42 or wr > 0.58 else 'black')
plt.colorbar(im, ax=ax, label='Win rate')
ax.set_title('Metal Skin × Vyper — win rate 2×2\n(high rank, avg_badge ≥ 100)', fontsize=11)
plt.tight_layout()
plt.show()
# Out:
#      enemy_vyper      held_metal_skin      n   wins  win_rate
# 0   Vyper absent  Metal Skin NOT held  22675  11654     0.514
# 1   Vyper absent      Metal Skin held   4885   2123     0.435
# 2  Vyper present  Metal Skin NOT held   2023   1077     0.532
# 3  Vyper present      Metal Skin held    639    260     0.407

# %% [markdown]
# ## 4. Core builders vs situational buyers
#
# Split the Metal Skin holders into:
# - **Core builders**: heroes whose hold rate ≥ 20% (they build it most games regardless)
# - **Situational buyers**: everyone else
#
# Then check whether the lose-more signal against Vyper comes from core builders (confound) or situational buyers (genuine panic-buy pattern).

# %%
CORE_THRESHOLD = 0.20

core_heroes = set(
    metal_skin_by_hero[metal_skin_by_hero['hold_rate'] >= CORE_THRESHOLD]['hero_id']
)
print(f'Core Metal Skin builders (hold rate ≥ {CORE_THRESHOLD:.0%}):')
print(metal_skin_by_hero[metal_skin_by_hero['hold_rate'] >= CORE_THRESHOLD][['hero_name', 'hold_rate']].to_string(index=False))

has_core_builder = (
    players_df[players_df['hero_id'].isin(core_heroes)]
    .groupby(['match_id', 'team'])
    .size().gt(0).astype(int)
    .rename('has_core_builder')
    .reset_index()
)

team_df3 = team_df2.merge(has_core_builder, on=['match_id', 'team'], how='left')
team_df3['has_core_builder'] = team_df3['has_core_builder'].fillna(0).astype(int)

rows = []
for builder_label, builder_mask in [('Core builder on team', 1), ('No core builder', 0)]:
    for vyp_label, vyp_mask in [('Vyper present', 1), ('Vyper absent', 0)]:
        grp  = team_df3[
            (team_df3['has_core_builder'] == builder_mask) &
            (team_df3['enemy_vyper']      == vyp_mask)
        ]
        held     = grp[grp['held_metal_skin'] == 1]['won']
        not_held = grp[grp['held_metal_skin'] == 0]['won']
        rows.append({
            'group':       builder_label,
            'matchup':     vyp_label,
            'n_held':      len(held),
            'n_not_held':  len(not_held),
            'wr_held':     held.mean()     if len(held)     > 0 else np.nan,
            'wr_not_held': not_held.mean() if len(not_held) > 0 else np.nan,
        })

breakdown_df = pd.DataFrame(rows)
breakdown_df['wr_delta'] = breakdown_df['wr_held'] - breakdown_df['wr_not_held']
display(breakdown_df.round(3))

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=True)
vyp_labels   = ['Vyper absent', 'Vyper present']
group_labels = ['Core builder on team', 'No core builder']
x = np.arange(len(vyp_labels))
w = 0.35

for ax, group in zip(axes, group_labels):
    sub = breakdown_df[breakdown_df['group'] == group].set_index('matchup').reindex(vyp_labels)
    ax.bar(x - w/2, sub['wr_held'],     w, label='Metal Skin held',     color='firebrick',   alpha=0.85)
    ax.bar(x + w/2, sub['wr_not_held'], w, label='Metal Skin not held', color='lightsalmon', alpha=0.85)
    for i, row in enumerate(sub.itertuples()):
        if pd.isna(row.wr_delta): continue
        color = 'green' if row.wr_delta > 0 else 'red'
        ax.annotate(f'{row.wr_delta:+.1%}',
                    xy=(i, max(row.wr_held or 0, row.wr_not_held or 0) + 0.01),
                    ha='center', fontsize=9, color=color, fontweight='bold')
    ax.axhline(0.5, color='grey', linewidth=0.8, linestyle='--')
    ax.set_xticks(x); ax.set_xticklabels(vyp_labels, fontsize=9)
    ax.set_ylim(0, 0.80); ax.set_ylabel('Win rate')
    ax.set_title(group)
    ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=1))
    ax.legend(fontsize=8); ax.grid(axis='y', alpha=0.3)

fig.suptitle('Metal Skin win rate: core builders vs situational buyers × Vyper matchup',
             fontsize=11)
plt.tight_layout()
plt.show()
# Out:
# Core Metal Skin builders (hold rate ≥ 20%):
# Empty DataFrame
# Columns: [hero_name, hold_rate]
# Index: []
#                   group        matchup  n_held  n_not_held  wr_held  \
# 0  Core builder on team  Vyper present       0           0      NaN
# 1  Core builder on team   Vyper absent       0           0      NaN
# 2       No core builder  Vyper present     639        2023    0.407
# 3       No core builder   Vyper absent    4885       22675    0.435
#
#    wr_not_held  wr_delta
# 0          NaN       NaN
# 1          NaN       NaN
# 2        0.532    -0.125
# 3        0.514    -0.079
